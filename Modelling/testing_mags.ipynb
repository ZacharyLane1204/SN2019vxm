# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib widget

# %%
file = '/Users/zgl12/Modules/SN2019vxm/Data/collated_vxm_data_with_tess.csv'

df = pd.read_csv(file)

df = df[(df['Observatory'] == 'ATLAS') & (df['MJD'] < 59500)]
df
# Out:
#      Unnamed: 0           MJD Observatory Filter         Svo_filter  \
# 40           40  57933.524353       ATLAS      o  Misc/Atlas.orange
# 41           41  57969.445282       ATLAS      o  Misc/Atlas.orange
# 42           42  57982.423870       ATLAS      o  Misc/Atlas.orange
# 43           43  58010.324072       ATLAS      o  Misc/Atlas.orange
# 44           44  58110.211618       ATLAS      o  Misc/Atlas.orange
# ..          ...           ...         ...    ...                ...
# 230         230  59374.513241       ATLAS      c    Misc/Atlas.cyan
# 231         231  59382.559966       ATLAS      c    Misc/Atlas.cyan
# 232         232  59434.478650       ATLAS      c    Misc/Atlas.cyan
# 233         233  59438.467837       ATLAS      c    Misc/Atlas.cyan
# 234         234  59464.370929       ATLAS      c    Misc/Atlas.cyan
#
#            Flux     d_Flux        Mag     d_Mag  WavelengthEff  FrequencyEff
# ...

# %%
plt.figure()
plt.scatter(df.MJD.values, df.Mag.values)
plt.gca().invert_yaxis()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
