# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib widget

# %%
df = pd.read_csv("/Users/zgl12/Documents/collated_vxm_data_with_tess.csv")
df = df[(df['MJD'] >= 58804.03) & (df['MJD'] <= 58804.03 + 200) & (df['Flux'] >= 0)]  # after discovery

df = df.drop(columns=['Unnamed: 0'])

# %%
len(df)
# Out:
# 234

# %%
df['Observatory'].unique()
# Out:
# array(['TESS', 'ATLAS', 'Siding Springs', 'Swift', 'Gaia', 'Konkoly'],
#       dtype=object)

# %%
df.to_csv("../Data/mosfit_collated_vxm_data_with_tess.csv", index=False)
