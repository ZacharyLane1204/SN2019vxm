# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib widget

# %%
file = '/Users/zgl12/ATClean/output/misc/2019vxm/2019vxm.o.clean.lc.txt'

# %%
df = pd.read_csv(file, delim_whitespace=True)
# Out:
# /var/folders/6v/pg_c9mqn3gn45gn_zmvy9w9cvfsx9j/T/ipykernel_37800/2961836325.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file, delim_whitespace=True)

# %%
df
# Out:
#                MJD       m       dm    uJy  duJy  F  err    chi/N         RA  \
# 0     57233.373157  19.919    0.855     39    33  o    0     2.00  299.61892
# 1     57233.409910  19.168    0.478     78    37  o    0     5.05  299.61892
# 2     57234.372875 -21.423    4.000    -10    39  o    0     2.12  299.61892
# 3     57320.254883  18.253    0.263    182    48  o    0     9.04  299.61892
# 4     57320.276640  18.667    0.429    124    53  o    0    12.00  299.61892
# ...            ...     ...      ...    ...   ... ..  ...      ...        ...
# 2757  60768.606100  20.325    0.951     27    26  o    0     0.75  299.61892
# 2758  60768.610429  18.467    0.095    149    14  o    0     6.33  299.61892
# 2759  60768.617859 -24.773  136.000      0    61  o    0     0.59  299.61892
# 2760  60768.623077  21.368    3.063     10    32  o    0     0.71  299.61892
# 2761  60769.580261  13.764    0.005  11339    61  o    0  1189.48  299.61892
#
# ...

# %%
mask = (df['Mask'] == '0x0000') & (df['duJy'] < 100)

plt.figure()
plt.errorbar(df['MJD'][mask], df['uJy'][mask], df['duJy_new'][mask], label='Flux', fmt ='.')
plt.xlabel('MJD')
plt.ylabel('Flux (uJy)')
# plt.title('2019vxm')
# plt.legend()
# plt.grid()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
