# %%
import pandas as pd
import numpy as np

# %%
file = '/Users/zgl12/Downloads/Summary_table (1).txt'

df  = pd.read_csv(file, delim_whitespace=True)

# %%
lengths = []

for i in range(11, 25):
    lengths.append(len(df[df['GRB_name'].str.startswith(f'GRB{i}')]))
    
np.nanmean(lengths), np.nanstd(lengths, ddof = 1)
# Out:
# (304.57142857142856, 13.042618222960071)

# %%
lengths
# Out:
# [295, 297, 306, 317, 315, 290, 320, 319, 295, 324, 309, 282, 293, 302]
