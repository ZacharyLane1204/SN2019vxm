# %%
import tessreduce as tr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tqdm import tqdm

from vxm_control_lightcurves import *

# %%
df = pd.read_csv('/Users/zgl12/Python_Scripts/SN2019VXM/TESS_Outlines/s18_4_1_control_curves.csv')

ras = df['RA'].values
decs = df['DEC'].values

# %%
for ra, dec in tqdm(zip(ras, decs)):
    tess_reducing(ra, dec)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib widget

# %%
lc = np.load('/Users/zgl12/Downloads/s80_flux_reduced_dev.npy')

# %%
lc.shape
# Out:
# (11120, 90, 90)

# %%
import tessreduce as tr
import matplotlib.pyplot as plt

# %matplotlib widget

# %%
obs = tr.spacetime_lookup(284.689875, -7.873944, time=60858, print_table=True)

# %%
# tess = tr.tessreduce(obs_list=obs, plot = True, phot_method = 'aperture', calibrate = True, num_cores=3)

# %%
tess_psf = tr.tessreduce(obs_list=obs, plot = True, phot_method = 'aperture', calibrate = False, num_cores=3)

# %%
# plt.figure()
# plt.scatter(tess.lc[0], tess.lc[1], tess.lc[2], color = 'k', marker = '.')
# plt.show()

# %%
plt.figure()
plt.scatter(tess_psf.lc[0], tess_psf.lc[1], tess_psf.lc[2], color = 'k', marker = '.')
plt.show()
