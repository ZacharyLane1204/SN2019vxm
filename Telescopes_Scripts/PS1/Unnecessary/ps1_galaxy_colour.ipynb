# %%
import numpy as np
import pandas as pd

# %%
file = '../../Data/ps1_galaxy.csv'

df = pd.read_csv(file)

df
# Out:
#                 objID    raMean    decMean  qualityFlag  gMeanPSFMag  \
# 0  182562996106752735  299.6107  62.134979          108       13.456
#
#    gMeanPSFMagErr  gMeanPSFMagNpt  rMeanPSFMag  rMeanPSFMagErr  \
# 0          -999.0               0        13.18          -999.0
#
#    rMeanPSFMagNpt  ...  gFlags  gQfPerfect  rFlags  rQfPerfect  iFlags  \
# 0               0  ...  114724      -999.0  114724      -999.0  114724
#
#    iQfPerfect    zFlags  zQfPerfect  yFlags  yQfPerfect
# 0      -999.0  16892216    0.999141  115000    0.999729
#
# [1 rows x 34 columns]

# %%
gMeanPSFMag = df['gMeanPSFMag']
rMeanPSFMag = df['rMeanPSFMag']
iMeanPSFMag = df['iMeanPSFMag']
zMeanPSFMag = df['zMeanPSFMag']
yMeanPSFMag = df['yMeanPSFMag']

# %%
float(gMeanPSFMag - rMeanPSFMag), float(rMeanPSFMag - iMeanPSFMag), float(gMeanPSFMag - iMeanPSFMag), float(iMeanPSFMag - zMeanPSFMag)
